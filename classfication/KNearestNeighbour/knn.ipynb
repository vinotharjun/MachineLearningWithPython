# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %% [markdown]
# # Example with dummy dataset

# %%
# create dummy sets
import matplotlib
x=np.array([np.array([1,2]),
            np.array([2,3]),
            np.array([3,1]),
            np.array([6,5]),
            np.array([7,7]),
            np.array([8,6]),
            np.array([1,1]), 
            np.array([8,8]),
            np.array([6,8]),
            np.array([2,4]),] )
y=np.array([0,0,0,1,1,1,0,1,1,0])

# %%
# x
# x[0]=tumor's height
# x[1]=tumor'width
# y=0  no change of cancer
# y=1 chance of cancer

# %%
data=pd.DataFrame(x,columns=["height","width"])
data["cancer"]=y

# %%
data
# Out:
#    height  width  cancer
# 0       1      2       0
# 1       2      3       0
# 2       3      1       0
# 3       6      5       1
# 4       7      7       1
# 5       8      6       1
# 6       1      1       0
# 7       8      8       1
# 8       6      8       1
# 9       2      4       0

# %%
# colors = ['red','green']

plt.scatter(x[:,0], x[:,1])

# %%
colors = ['green','red']

plt.scatter(x[:,0], x[:,1], c=y, cmap=matplotlib.colors.ListedColormap(colors))
plt.xlabel("height")
plt.ylabel("width")
# Out:
# Text(0,0.5,'width')

# %%
new_features=[2,2]
fig, ax = plt.subplots()
ax.scatter(x[:,0], x[:,1], c=y, cmap=matplotlib.colors.ListedColormap(colors))
ax.scatter(new_features[0],new_features[1] )

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=3)

# %%
model.fit(x,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
tumor_test_data=np.array([new_features])
model.predict(tumor_test_data)
# Out:
# array([0])

# %%
data=pd.read_csv("./Social_Network_Ads.csv")

# %%
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# 5    15728773    Male   27            58000          0
# 6    15598044  Female   27            84000          0
# 7    15694829  Female   32           150000          1
# 8    15600575    Male   25            33000          0
# 9    15727311  Female   35            65000          0
# 10   15570769  Female   26            80000          0
# 11   15606274  Female   26            52000          0
# 12   15746139    Male   20            86000          0
# 13   15704987    Male   32            18000          0
# 14   15628972    Male   18            82000          0
# 15   15697686    Male   29            80000          0
# ...

# %%
from sklearn.model_selection import train_test_split
train_data,test_data= train_test_split(data,test_size=0.2)

# %%
X_train = train_data.iloc[:, [2, 3]].values
y_train = train_data.iloc[:, 4].values
X_test=test_data.iloc[:,[2,3]].values
y_test=test_data.iloc[:,4].values

# %% [markdown]
# # Data preprocessing

# %%
#x-mean/max-min
#1,2,3,4

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# Out:
# C:\Users\solai\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors = 3)
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
y_predicted=model.predict(X_test)

# %%
# y_test

# %%
test_data["predicted"]=y_predicted
# Out:
# C:\Users\solai\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test_data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased  predicted
# 34   15724858    Male   27            90000          0          0
# 140  15807909    Male   19            85000          0          0
# 376  15596984  Female   46            74000          0          0
# 28   15744529    Male   29            43000          0          0
# 87   15631912  Female   28            85000          0          0
# 275  15727467    Male   57            74000          1          1
# 284  15638646    Male   48           141000          0          1
# 270  15680752  Female   43           133000          0          1
# 217  15582066    Male   40            78000          0          0
# 215  15779529  Female   60           108000          1          1
# 194  15689751    Male   28            89000          0          0
# 75   15651983    Male   34           112000          1          0
# 199  15708228    Male   35            22000          0          0
# ...

# %%
age=10
salary=4400000000
test=np.array([[age,salary]])
test=sc.transform(test)
model.predict(test)
# Out:
# C:\Users\solai\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([1], dtype=int64)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)

# %%
pd.DataFrame(cm)
# Out:
#     0   1
# 0  46   4
# 1   8  22

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_predicted)
